# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f1=pd.read_csv('fandango_scrape.csv')

# %%
f1
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 499                      Valiyavan (2015)    0.0     0.0      0
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 503                         Zarafa (2012)    0.0     0.0      0
#
# [504 rows x 4 columns]

# %%
plt.figure(figsize=(10,10),dpi=200)
sns.scatterplot(data=f1,x='RATING',y='VOTES')
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='VOTES'>

# %%
title='filmtitle (year)'

# %%
title.split('(')[-1].replace(')','')
# Out:
# 'year'

# %%
f1['YEAR']=f1['FILM'].apply(lambda title:title.split('(')[-1].replace(')',''))

# %%
f1
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
f2=f1['YEAR'].value_counts()

# %%
sns.countplot(data=f1,x='YEAR');

# %%
sum(f1['VOTES']== 0)
# Out:
# 69

# %%
f_review=f1[f1['VOTES']>0]

# %%
f_review
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1          Jurassic World (2015)    4.5     4.5  34390  2015
# 2         American Sniper (2015)    5.0     4.8  34085  2015
# 3               Furious 7 (2015)    5.0     4.8  33538  2015
# 4              Inside Out (2015)    4.5     4.5  15749  2015
# ..                           ...    ...     ...    ...   ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015
# 431            The Intern (2015)    5.0     5.0      1  2015
# 432        The Park Bench (2015)    5.0     5.0      1  2015
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015
#
# [435 rows x 5 columns]

# %%
plt.figure(figsize=(14,8),dpi=200);
sns.kdeplot(data=f_review,x='RATING',clip=(0,5),fill=True,label='true reading');
sns.kdeplot(data=f_review,x='STARS',clip=(0,5),fill=True,label='star');
plt.legend(loc=(1.05,0.80));

# %%
f_review['star_diff']=f_review['STARS']-f_review['RATING']
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_12064\289510514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_review['star_diff']=f_review['STARS']-f_review['RATING']

# %%
f_review
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  star_diff
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015        0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015        0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015        0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015        0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015        0.0
# ..                           ...    ...     ...    ...   ...        ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015        0.0
# 431            The Intern (2015)    5.0     5.0      1  2015        0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015        0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015        0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015        0.0
#
# [435 rows x 6 columns]

# %%
f_review['star_diff']=f_review['star_diff'].round(2)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_12064\3883982095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_review['star_diff']=f_review['star_diff'].round(2)

# %%
f_review
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  star_diff
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015        0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015        0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015        0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015        0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015        0.0
# ..                           ...    ...     ...    ...   ...        ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015        0.0
# 431            The Intern (2015)    5.0     5.0      1  2015        0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015        0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015        0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015        0.0
#
# [435 rows x 6 columns]

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.countplot(data=f_review,x='star_diff',palette='magma');

# %%
f_review[f_review['star_diff']==1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  star_diff
# 381  Turbo Kid (2015)    5.0     4.0      2  2015        1.0

# %%
allo=pd.read_csv('all_sites_scores.csv')

# %%
allo
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
#allo=allo.set_index('FILM')
#allo

# %%
name='film_name (year)'

# %%
name.split('(')[-1].replace(')','')
# Out:
# 'year'

# %%
allo['Year']=allo['FILM'].apply(lambda name:name.split('(')[-1].replace(')',''))

# %%
allo
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(data=allo,x='RottenTomatoes',y='RottenTomatoes_User');
plt.ylim(0,100)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
allo['review_diff']=allo['RottenTomatoes']-allo['RottenTomatoes_User']

# %%
allo
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
#allo['review_diff']=allo['review_diff']>0

# %%
#allo

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.histplot(data=allo,x='review_diff',kde=True)
# Out:
# <AxesSubplot:xlabel='review_diff', ylabel='Count'>

# %%
allo.nsmallest(5,'review_diff')
# Out:
#                           FILM  RottenTomatoes  RottenTomatoes_User  \
# 3       Do You Believe? (2015)              18                   84
# 85           Little Boy (2015)              20                   81
# 105    Hitman: Agent 47 (2015)               7                   49
# 134    The Longest Ride (2015)              31                   73
# 125  The Wedding Ringer (2015)              27                   66
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 3            22              4.7   5.4                          31
# 85           30              5.9   7.4                          38
# 105          28              3.3   5.9                          67
# 134          33              4.8   7.2                          49
# 125          35              3.3   6.7                         126
#
#      IMDB_user_vote_count  Year  review_diff
# 3                    3136  2015          -66
# 85                   5927  2015          -61
# ...

# %%
allo.nlargest(5,'review_diff')
# Out:
#                                  FILM  RottenTomatoes  RottenTomatoes_User  \
# 69                  Mr. Turner (2014)              98                   56
# 112                 It Follows (2015)              96                   65
# 115          While We're Young (2015)              83                   52
# 37               Welcome to Me (2015)              71                   47
# 40   I'll See You In My Dreams (2015)              94                   70
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 69           94              6.6   6.9                          98
# 112          83              7.5   6.9                         551
# 115          76              6.7   6.4                          65
# 37           67              6.9   5.9                          33
# 40           75              6.9   6.9                          14
#
#      IMDB_user_vote_count  Year  review_diff
# 69                  13296  2014           42
# ...

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(data=allo,x='Metacritic',y='Metacritic_User');
plt.ylim(0,10)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(data=allo,x='Metacritic_user_vote_count',y='IMDB_user_vote_count');
#plt.ylim(0,10)
#plt.xlim(0,100)

# %%
allo.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Year  review_diff
# 14                334164  2014           -2

# %%
allo.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Year  review_diff
# 88                292023  2015            9

# %%
allo=pd.read_csv('all_sites_scores.csv')

# %%
allo
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
sns.scatterplot(data=allo,x='RottenTomatoes',y='RottenTomatoes_User')
plt.ylim(0,100)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
allo['rot_diff']=allo['RottenTomatoes']-allo['RottenTomatoes_User']

# %%
allo
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df=pd.merge(f1,allo,on='FILM',how='inner')

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
import numpy as np
df.max()
# Out:
# FILM                          Woman in Gold (2015)
# STARS                                          5.0
# RATING                                         4.8
# VOTES                                        34846
# YEAR                                          2015
# RottenTomatoes                                 100
# RottenTomatoes_User                             94
# Metacritic                                      94
# Metacritic_User                                9.6
# IMDB                                           8.6
# Metacritic_user_vote_count                    2375
# IMDB_user_vote_count                        334164
# rot_diff                                        42
# dtype: object

# %%
df['rt_nom']=np.round(df['RottenTomatoes']/20,1)
df['rt_nomu']=np.round(df['RottenTomatoes_User']/20,1)
df['met_nom']=np.round(df['Metacritic']/20,1)
df['met_nomu']=np.round(df['Metacritic_User']/2,1)
df['imbd_nom']=np.round(df['IMDB']/2,1)

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'rot_diff',
#        'rt_nom', 'rt_nomu', 'met_nom', 'met_nomu', 'imbd_nom'],
#       dtype='object')

# %%
norm_rat=df[['RATING','STARS','rt_nom','rt_nomu','met_nom','met_nomu','imbd_nom']]

# %%
norm_rat
# Out:
#      RATING  STARS  rt_nom  rt_nomu  met_nom  met_nomu  imbd_nom
# 0       3.9    4.0     1.2      2.1      2.3       1.6       2.1
# 1       4.5    4.5     3.6      4.0      3.0       3.5       3.6
# 2       4.8    5.0     3.6      4.2      3.6       3.3       3.7
# 3       4.8    5.0     4.0      4.2      3.4       3.4       3.7
# 4       4.5    4.5     4.9      4.5      4.7       4.4       4.3
# ..      ...    ...     ...      ...      ...       ...       ...
# 140     3.5    3.5     4.4      3.2      3.4       3.2       3.4
# 141     3.6    4.0     4.8      4.0      4.4       3.2       3.5
# 142     4.2    4.5     4.6      4.2      3.4       3.5       3.9
# 143     3.9    4.0     4.8      4.3      4.3       3.6       3.7
# 144     3.1    3.5     3.0      2.3      3.4       2.9       3.2
#
# [145 rows x 7 columns]

# %%
plt.figure(figsize=(16,5))
sns.kdeplot(data=norm_rat,shade=True,clip=[0,5])
# Out:
# <AxesSubplot:ylabel='Density'>
